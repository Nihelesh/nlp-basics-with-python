# %%
#importing libraries
import spacy
# Load the English language model
nlp = spacy.load("en_core_web_sm")
# Sample text
text = "Numpy and Pandas library are ued for data science."
# Process the text with SpaCy
doc = nlp(text)
# Display the PoS tagged result
print("Original Text: ", text)
print("PoS Tagging Result:")
for token in doc:
 print(f"{token.text}: {token.pos_}")
# Out:
# Original Text:  Numpy and Pandas library are ued for data science.
# PoS Tagging Result:
# Numpy: ADJ
# and: CCONJ
# Pandas: PROPN
# library: NOUN
# are: AUX
# ued: ADJ
# for: ADP
# data: NOUN
# science: NOUN
# .: PUNCT
