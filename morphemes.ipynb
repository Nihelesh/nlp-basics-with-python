# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihelesh/nlp-basics-with-python/blob/main/morphemes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from word_forms.word_forms import get_word_forms
word_forms = get_word_forms("president")
print(word_forms)
verb_forms = get_word_forms("sit")
print(verb_forms['v'])
noun_forms = get_word_forms("cat")
print(noun_forms['n'])
adjective_forms = get_word_forms("generous")
print(adjective_forms['a'])
from word_forms.word_forms import get_word_forms
def lemmatize(word):
 all_forms = [word for pos_form in get_word_forms(word).values() for word in pos_form]
 all_forms.sort()
 all_forms.sort(key=len)
 try:
  return all_forms[0]
 except IndexError:
  raise ValueError("{} is not a real word".format(word))
lemmatize('dancing')
# Out:
# {'n': {'presidentships', 'presidencies', 'presidentship', 'president', 'presidents', 'presidency'}, 'a': {'presidential'}, 'v': {'presiding', 'preside', 'presides', 'presided'}, 'r': {'presidentially'}}
# {'sitting', 'sits', 'sit', 'sat'}
# {'cattiness', 'cattinesses', 'cat', 'cats', 'catties', 'catty'}
# {'generous'}
# 'dance'

# %%
# !pip install word_forms
# Out:
# Collecting word_forms
#   Downloading word_forms-2.1.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting inflect==4.1.0 (from word_forms)
#   Downloading inflect-4.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: nltk>=3.3 in /usr/local/lib/python3.12/dist-packages (from word_forms) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.3->word_forms) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.3->word_forms) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.3->word_forms) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.3->word_forms) (4.67.1)
# Downloading word_forms-2.1.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.3/166.3 kB 4.9 MB/s eta 0:00:00
# Downloading inflect-4.1.0-py3-none-any.whl (31 kB)
# Installing collected packages: inflect, word_forms
#   Attempting uninstall: inflect
#     Found existing installation: inflect 7.5.0
#     Uninstalling inflect-7.5.0:
#       Successfully uninstalled inflect-7.5.0
# Successfully installed inflect-4.1.0 word_forms-2.1.0
